# %%
"""

    Binning is nothing we are grouping
    datasets into several chunks.
    
    Binning is useful for data pre-processing.
    
"""
import pandas as pd

inFile = 'files/finalData.csv'
df = pd.read_csv(inFile)

binwidth = (df["price"].max() - df["price"].min())//4
bins = range(df["price"].min(), df["price"].max(), binwidth)
group_name = ['low','medium','high']

df['price-binned'] = pd.qcut(df["price"], 3, labels=group_name)

"""
    One hot enchoding or converting string data into
    some numerical values.
    
"""
data = pd.get_dummies(df["fuel-type"])
df['oneHot_Diesel'] = data['diesel']
df['oneHot_Gas'] = data['gas']
df.to_csv('files/cleanedData.csv')
df.head()
# print(pd.get_dummies(df["fuel-type"]))
# Out:
#    Unnamed: 0  symboling  normalized-losses  make fuel-type aspiration  \
# 0           3          2                164  audi       gas        std
# 1           4          2                164  audi       gas        std
# 2           6          1                158  audi       gas        std
# 3           8          1                158  audi       gas      turbo
# 4          10          2                192   bmw       gas        std
#
#   num-of-doors body-style drive-wheels engine-location  ...  stroke  \
# 0         four      sedan          fwd           front  ...     3.4
# 1         four      sedan          4wd           front  ...     3.4
# 2         four      sedan          fwd           front  ...     3.4
# 3         four      sedan          fwd           front  ...     3.4
# 4          two      sedan          rwd           front  ...     2.8
#
#    compression-ratio  horsepower  peak-rpm  city-L/100KM highway-L/100KM  \
# ...
